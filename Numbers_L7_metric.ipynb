# %%
import re

# %%
filename_L4_15 = 'explore_footprints_L7_15.txt'
filename_L4_16 = 'explore_footprints_L7_16.txt'
filename_L4_17 = 'explore_footprints_L7_17.txt'
#could change filenames to say L7 or not have type at all but didn't bother.

# %%
baseline_L4_15 = 225779.2804859185
baseline_L4_16 = 222163.27262236737
baseline_L4_17 = 212840.27030771854     #smaller because two snaps

# %%
#this cell intentionally left blank

# %%
fileL4_15 = open(filename_L4_15, 'r')
Lines = fileL4_15.readlines()
for line in Lines:
    cutline=re.sub(".*:"," ",line)
    keep=cutline[0:12]
    grabname=re.sub("{'VolumeSum'.*","",line)
    volume=float(keep)
    fL4 = volume/baseline_L4_15
    print("{0:.3f}".format(fL4),grabname[10:])
    #print("{0:.3f}".format(fL4))
# Out:
# 1.032 fbs_1.5/alt_roll_dust/alt_dust_v1.5_10yrs.db
#
# 1.025 fbs_1.5/alt_roll_dust/alt_roll_mod2_dust_sdf_0.20_v1.5_10yrs.db
#
# 1.031 fbs_1.5/alt_roll_dust/roll_mod2_dust_sdf_0.20_v1.5_10yrs.db
#
# 0.965 fbs_1.5/baseline/baseline_2snaps_v1.5_10yrs.db
#
# 1.000 fbs_1.5/baseline/baseline_v1.5_10yrs.db
#
# 1.047 fbs_1.5/bulge/bulges_bs_v1.5_10yrs.db
#
# 1.054 fbs_1.5/bulge/bulges_bulge_wfd_v1.5_10yrs.db
#
# 1.046 fbs_1.5/bulge/bulges_cadence_bs_v1.5_10yrs.db
#
# 1.052 fbs_1.5/bulge/bulges_cadence_bulge_wfd_v1.5_10yrs.db
#
# 1.051 fbs_1.5/bulge/bulges_cadence_i_heavy_v1.5_10yrs.db
#
# 1.051 fbs_1.5/bulge/bulges_i_heavy_v1.5_10yrs.db
#
# 0.977 fbs_1.5/daily_ddf/daily_ddf_v1.5_10yrs.db
#
# 0.990 fbs_1.5/dcr/dcr_nham1_ug_v1.5_10yrs.db
#
# 0.996 fbs_1.5/dcr/dcr_nham1_ugr_v1.5_10yrs.db
#
# 0.992 fbs_1.5/dcr/dcr_nham1_ugri_v1.5_10yrs.db
#
# 0.992 fbs_1.5/dcr/dcr_nham2_ug_v1.5_10yrs.db
#
# 0.992 fbs_1.5/dcr/dcr_nham2_ugr_v1.5_10yrs.db
#
# 0.991 fbs_1.5/dcr/dcr_nham2_ugri_v1.5_10yrs.db
#
# 0.919 fbs_1.5/filter_dist/filterdist_indx1_v1.5_10yrs.db
#
# 0.988 fbs_1.5/filter_dist/filterdist_indx2_v1.5_10yrs.db
#
# 0.935 fbs_1.5/filter_dist/filterdist_indx3_v1.5_10yrs.db
#
# 0.947 fbs_1.5/filter_dist/filterdist_indx4_v1.5_10yrs.db
#
# 1.100 fbs_1.5/filter_dist/filterdist_indx5_v1.5_10yrs.db
#
# 0.956 fbs_1.5/filter_dist/filterdist_indx6_v1.5_10yrs.db
#
# 0.958 fbs_1.5/filter_dist/filterdist_indx7_v1.5_10yrs.db
#
# 1.029 fbs_1.5/filter_dist/filterdist_indx8_v1.5_10yrs.db
#
# 1.003 fbs_1.5/footprints/footprint_add_mag_cloudsv1.5_10yrs.db
#
# 0.949 fbs_1.5/footprints/footprint_big_sky_dustv1.5_10yrs.db
#
# 0.913 fbs_1.5/footprints/footprint_big_sky_nouiyv1.5_10yrs.db
#
# 0.907 fbs_1.5/footprints/footprint_big_skyv1.5_10yrs.db
#
# 1.060 fbs_1.5/footprints/footprint_big_wfdv1.5_10yrs.db
#
# 0.901 fbs_1.5/footprints/footprint_bluer_footprintv1.5_10yrs.db
#
# 1.029 fbs_1.5/footprints/footprint_gp_smoothv1.5_10yrs.db
#
# 1.095 fbs_1.5/footprints/footprint_newAv1.5_10yrs.db
#
# 1.056 fbs_1.5/footprints/footprint_newBv1.5_10yrs.db
#
# 0.991 fbs_1.5/footprints/footprint_no_gp_northv1.5_10yrs.db
#
# 0.999 fbs_1.5/footprints/footprint_standard_goalsv1.5_10yrs.db
#
# 0.837 fbs_1.5/footprints/footprint_stuck_rollingv1.5_10yrs.db
#
# 0.978 fbs_1.5/goodseeing/goodseeing_gi_v1.5_10yrs.db
#
# 0.976 fbs_1.5/goodseeing/goodseeing_gri_v1.5_10yrs.db
#
# 0.989 fbs_1.5/goodseeing/goodseeing_griz_v1.5_10yrs.db
#
# 0.985 fbs_1.5/goodseeing/goodseeing_gz_v1.5_10yrs.db
#
# 0.987 fbs_1.5/goodseeing/goodseeing_i_v1.5_10yrs.db
#
# 0.993 fbs_1.5/greedy_footprint/greedy_footprint_v1.5_10yrs.db
#
# 0.980 fbs_1.5/rolling/rolling_mod2_sdf_0.10_v1.5_10yrs.db
#
# 0.975 fbs_1.5/rolling/rolling_mod2_sdf_0.20_v1.5_10yrs.db
#
# 0.964 fbs_1.5/rolling/rolling_mod3_sdf_0.10_v1.5_10yrs.db
#
# 0.965 fbs_1.5/rolling/rolling_mod3_sdf_0.20_v1.5_10yrs.db
#
# 0.950 fbs_1.5/rolling/rolling_mod6_sdf_0.10_v1.5_10yrs.db
#
# 0.954 fbs_1.5/rolling/rolling_mod6_sdf_0.20_v1.5_10yrs.db
#
# 0.982 fbs_1.5/same_filt/baseline_samefilt_v1.5_10yrs.db
#
# 0.988 fbs_1.5/short_exp/short_exp_2ns_1expt_v1.5_10yrs.db
#
# 0.983 fbs_1.5/short_exp/short_exp_2ns_5expt_v1.5_10yrs.db
#
# 0.980 fbs_1.5/short_exp/short_exp_5ns_1expt_v1.5_10yrs.db
#
# 0.968 fbs_1.5/short_exp/short_exp_5ns_5expt_v1.5_10yrs.db
#
# 1.001 fbs_1.5/spiders/spiders_v1.5_10yrs.db
#
# 0.990 fbs_1.5/third_obs/third_obs_pt120v1.5_10yrs.db
#
# 1.000 fbs_1.5/third_obs/third_obs_pt15v1.5_10yrs.db
#
# 1.000 fbs_1.5/third_obs/third_obs_pt30v1.5_10yrs.db
#
# 1.000 fbs_1.5/third_obs/third_obs_pt45v1.5_10yrs.db
#
# 0.995 fbs_1.5/third_obs/third_obs_pt60v1.5_10yrs.db
#
# 0.995 fbs_1.5/third_obs/third_obs_pt90v1.5_10yrs.db
#
# 1.012 fbs_1.5/twilight_neo/twilight_neo_mod1_v1.5_10yrs.db
#
# 1.014 fbs_1.5/twilight_neo/twilight_neo_mod2_v1.5_10yrs.db
#
# 1.007 fbs_1.5/twilight_neo/twilight_neo_mod3_v1.5_10yrs.db
#
# 1.003 fbs_1.5/twilight_neo/twilight_neo_mod4_v1.5_10yrs.db
#
# 0.987 fbs_1.5/u60/u60_v1.5_10yrs.db
#
# 0.999 fbs_1.5/var_expt/var_expt_v1.5_10yrs.db
#
# 1.025 fbs_1.5/wfd_depth/wfd_depth_scale0.65_noddf_v1.5_10yrs.db
#
# 1.006 fbs_1.5/wfd_depth/wfd_depth_scale0.65_v1.5_10yrs.db
#
# 1.023 fbs_1.5/wfd_depth/wfd_depth_scale0.70_noddf_v1.5_10yrs.db
#
# 1.005 fbs_1.5/wfd_depth/wfd_depth_scale0.70_v1.5_10yrs.db
#
# 1.021 fbs_1.5/wfd_depth/wfd_depth_scale0.75_noddf_v1.5_10yrs.db
#
# 1.004 fbs_1.5/wfd_depth/wfd_depth_scale0.75_v1.5_10yrs.db
#
# 1.011 fbs_1.5/wfd_depth/wfd_depth_scale0.80_noddf_v1.5_10yrs.db
#
# 0.998 fbs_1.5/wfd_depth/wfd_depth_scale0.80_v1.5_10yrs.db
#
# 1.009 fbs_1.5/wfd_depth/wfd_depth_scale0.85_noddf_v1.5_10yrs.db
#
# 0.996 fbs_1.5/wfd_depth/wfd_depth_scale0.85_v1.5_10yrs.db
#
# 1.007 fbs_1.5/wfd_depth/wfd_depth_scale0.90_noddf_v1.5_10yrs.db
#
# 1.000 fbs_1.5/wfd_depth/wfd_depth_scale0.90_v1.5_10yrs.db
#
# 1.003 fbs_1.5/wfd_depth/wfd_depth_scale0.95_noddf_v1.5_10yrs.db
#
# 0.988 fbs_1.5/wfd_depth/wfd_depth_scale0.95_v1.5_10yrs.db
#
# 1.002 fbs_1.5/wfd_depth/wfd_depth_scale0.99_noddf_v1.5_10yrs.db
#
# 0.990 fbs_1.5/wfd_depth/wfd_depth_scale0.99_v1.5_10yrs.db

# %%
fileL4_16 = open(filename_L4_16, 'r')
Lines = fileL4_16.readlines()
for line in Lines:
    cutline=re.sub(".*:"," ",line)
    keep=cutline[0:12]
    grabname=re.sub("{'VolumeSum'.*","",line)
    volume=float(keep)
    fL4 = volume/baseline_L4_16
    print("{0:.3f}".format(fL4),grabname[10:])
    #print("{0:.3f}".format(fL4))
# Out:
# 1.005 fbs_1.6/even_filters/even_filters_alt_g_v1.6_10yrs.db
#
# 1.000 fbs_1.6/even_filters/even_filters_altv1.6_10yrs.db
#
# 1.008 fbs_1.6/even_filters/even_filters_g_v1.6_10yrs.db
#
# 1.006 fbs_1.6/even_filters/even_filtersv1.6_10yrs.db
#
# 0.920 fbs_1.6/potential_schedulers/barebones_nexp2_v1.6_10yrs.db
#
# 0.958 fbs_1.6/potential_schedulers/barebones_v1.6_10yrs.db
#
# 1.000 fbs_1.6/potential_schedulers/baseline_nexp1_v1.6_10yrs.db
#
# 0.955 fbs_1.6/potential_schedulers/baseline_nexp2_scaleddown_v1.6_10yrs.db
#
# 0.963 fbs_1.6/potential_schedulers/baseline_nexp2_v1.6_10yrs.db
#
# 0.995 fbs_1.6/potential_schedulers/combo_dust_nexp2_v1.6_10yrs.db
#
# 1.038 fbs_1.6/potential_schedulers/combo_dust_v1.6_10yrs.db
#
# 0.923 fbs_1.6/potential_schedulers/ddf_heavy_nexp2_v1.6_10yrs.db
#
# 0.963 fbs_1.6/potential_schedulers/ddf_heavy_v1.6_10yrs.db
#
# 0.935 fbs_1.6/potential_schedulers/dm_heavy_nexp2_v1.6_10yrs.db
#
# 0.970 fbs_1.6/potential_schedulers/dm_heavy_v1.6_10yrs.db
#
# 0.974 fbs_1.6/potential_schedulers/mw_heavy_nexp2_v1.6_10yrs.db
#
# 1.008 fbs_1.6/potential_schedulers/mw_heavy_v1.6_10yrs.db
#
# 0.973 fbs_1.6/potential_schedulers/rolling_exgal_mod2_dust_sdf_0.80_nexp2_v1.6_10yrs.db
#
# 1.014 fbs_1.6/potential_schedulers/rolling_exgal_mod2_dust_sdf_0.80_v1.6_10yrs.db
#
# 0.965 fbs_1.6/potential_schedulers/ss_heavy_nexp2_v1.6_10yrs.db
#
# 1.007 fbs_1.6/potential_schedulers/ss_heavy_v1.6_10yrs.db
#
# 1.002 fbs_1.6/rolling_fpo/rolling_fpo_2nslice0.8_v1.6_10yrs.db
#
# 1.003 fbs_1.6/rolling_fpo/rolling_fpo_2nslice0.9_v1.6_10yrs.db
#
# 1.002 fbs_1.6/rolling_fpo/rolling_fpo_2nslice1.0_v1.6_10yrs.db
#
# 0.990 fbs_1.6/rolling_fpo/rolling_fpo_3nslice0.8_v1.6_10yrs.db
#
# 0.990 fbs_1.6/rolling_fpo/rolling_fpo_3nslice0.9_v1.6_10yrs.db
#
# 0.987 fbs_1.6/rolling_fpo/rolling_fpo_3nslice1.0_v1.6_10yrs.db
#
# 0.994 fbs_1.6/rolling_fpo/rolling_fpo_6nslice0.8_v1.6_10yrs.db
#
# 0.993 fbs_1.6/rolling_fpo/rolling_fpo_6nslice0.9_v1.6_10yrs.db
#
# 0.994 fbs_1.6/rolling_fpo/rolling_fpo_6nslice1.0_v1.6_10yrs.db

# %%
fileL4_17 = open(filename_L4_17, 'r')
Lines = fileL4_17.readlines()
for line in Lines:
    cutline=re.sub(".*:"," ",line)
    keep=cutline[0:12]
    grabname=re.sub("{'VolumeSum'.*","",line)
    volume=float(keep)
    fL4 = volume/baseline_L4_17
    print("{0:.3f}".format(fL4),grabname[10:])
    #print("{0:.3f}".format(fL4))
# Out:
# 1.040 fbs_1.7/baseline/baseline_nexp1_v1.7_10yrs.db
#
# 1.000 fbs_1.7/baseline/baseline_nexp2_v1.7_10yrs.db
#
# 1.001 fbs_1.7/ddf_dither/ddf_dither0.00_v1.7_10yrs.db
#
# 1.000 fbs_1.7/ddf_dither/ddf_dither0.05_v1.7_10yrs.db
#
# 1.000 fbs_1.7/ddf_dither/ddf_dither0.10_v1.7_10yrs.db
#
# 1.001 fbs_1.7/ddf_dither/ddf_dither0.30_v1.7_10yrs.db
#
# 1.000 fbs_1.7/ddf_dither/ddf_dither0.70_v1.7_10yrs.db
#
# 1.001 fbs_1.7/ddf_dither/ddf_dither1.00_v1.7_10yrs.db
#
# 1.001 fbs_1.7/ddf_dither/ddf_dither1.50_v1.7_10yrs.db
#
# 1.000 fbs_1.7/ddf_dither/ddf_dither2.00_v1.7_10yrs.db
#
# 1.000 fbs_1.7/euclid_dither/euclid_dither1_v1.7_10yrs.db
#
# 1.001 fbs_1.7/euclid_dither/euclid_dither2_v1.7_10yrs.db
#
# 1.000 fbs_1.7/euclid_dither/euclid_dither3_v1.7_10yrs.db
#
# 1.000 fbs_1.7/euclid_dither/euclid_dither4_v1.7_10yrs.db
#
# 1.000 fbs_1.7/euclid_dither/euclid_dither5_v1.7_10yrs.db
#
# 1.013 fbs_1.7/footprint_tune/footprint_0_v1.710yrs.db
#
# 1.014 fbs_1.7/footprint_tune/footprint_1_v1.710yrs.db
#
# 1.010 fbs_1.7/footprint_tune/footprint_2_v1.710yrs.db
#
# 1.012 fbs_1.7/footprint_tune/footprint_3_v1.710yrs.db
#
# 1.003 fbs_1.7/footprint_tune/footprint_4_v1.710yrs.db
#
# 1.012 fbs_1.7/footprint_tune/footprint_5_v1.710yrs.db
#
# 1.010 fbs_1.7/footprint_tune/footprint_6_v1.710yrs.db
#
# 1.008 fbs_1.7/footprint_tune/footprint_7_v1.710yrs.db
#
# 1.003 fbs_1.7/footprint_tune/footprint_8_v1.710yrs.db
#
# 1.006 fbs_1.7/pair_times/pair_times_11_v1.7_10yrs.db
#
# 1.000 fbs_1.7/pair_times/pair_times_22_v1.7_10yrs.db
#
# 0.994 fbs_1.7/pair_times/pair_times_33_v1.7_10yrs.db
#
# 0.989 fbs_1.7/pair_times/pair_times_44_v1.7_10yrs.db
#
# 0.978 fbs_1.7/pair_times/pair_times_55_v1.7_10yrs.db
#
# 1.001 fbs_1.7/rolling/rolling_scale0.2_nslice2_v1.7_10yrs.db
#
# 1.001 fbs_1.7/rolling/rolling_scale0.2_nslice3_v1.7_10yrs.db
#
# 1.000 fbs_1.7/rolling/rolling_scale0.4_nslice2_v1.7_10yrs.db
#
# 1.002 fbs_1.7/rolling/rolling_scale0.4_nslice3_v1.7_10yrs.db
#
# 1.000 fbs_1.7/rolling/rolling_scale0.6_nslice2_v1.7_10yrs.db
#
# 1.003 fbs_1.7/rolling/rolling_scale0.6_nslice3_v1.7_10yrs.db
#
# 1.002 fbs_1.7/rolling/rolling_scale0.8_nslice2_v1.7_10yrs.db
#
# 1.007 fbs_1.7/rolling/rolling_scale0.8_nslice3_v1.7_10yrs.db
#
# 1.001 fbs_1.7/rolling/rolling_scale0.9_nslice2_v1.7_10yrs.db
#
# 1.006 fbs_1.7/rolling/rolling_scale0.9_nslice3_v1.7_10yrs.db
#
# 1.001 fbs_1.7/rolling/rolling_scale1.0_nslice2_v1.7_10yrs.db
#
# 1.006 fbs_1.7/rolling/rolling_scale1.0_nslice3_v1.7_10yrs.db
#
# 1.000 fbs_1.7/rolling_nm/rolling_nm_scale0.2_nslice2_v1.7_10yrs.db
#
# 1.000 fbs_1.7/rolling_nm/rolling_nm_scale0.2_nslice3_v1.7_10yrs.db
#
# 1.000 fbs_1.7/rolling_nm/rolling_nm_scale0.4_nslice2_v1.7_10yrs.db
#
# 1.003 fbs_1.7/rolling_nm/rolling_nm_scale0.4_nslice3_v1.7_10yrs.db
#
# 1.004 fbs_1.7/rolling_nm/rolling_nm_scale0.6_nslice2_v1.7_10yrs.db
#
# 1.006 fbs_1.7/rolling_nm/rolling_nm_scale0.6_nslice3_v1.7_10yrs.db
#
# 1.004 fbs_1.7/rolling_nm/rolling_nm_scale0.8_nslice2_v1.7_10yrs.db
#
# 1.010 fbs_1.7/rolling_nm/rolling_nm_scale0.8_nslice3_v1.7_10yrs.db
#
# 1.005 fbs_1.7/rolling_nm/rolling_nm_scale0.9_nslice2_v1.7_10yrs.db
#
# 1.007 fbs_1.7/rolling_nm/rolling_nm_scale0.9_nslice3_v1.7_10yrs.db
#
# 1.006 fbs_1.7/rolling_nm/rolling_nm_scale1.0_nslice2_v1.7_10yrs.db
#
# 1.013 fbs_1.7/rolling_nm/rolling_nm_scale1.0_nslice3_v1.7_10yrs.db
#
# 1.002 fbs_1.7/twi_pairs/twi_pairs_mixed_repeat_v1.7_10yrs.db
#
# 1.000 fbs_1.7/twi_pairs/twi_pairs_mixed_v1.7_10yrs.db
#
# 0.999 fbs_1.7/twi_pairs/twi_pairs_repeat_v1.7_10yrs.db
#
# 1.000 fbs_1.7/twi_pairs/twi_pairs_v1.7_10yrs.db
#
# 0.941 fbs_1.7/twi_neo/twi_neo_pattern1_v1.7_10yrs.db
#
# 0.972 fbs_1.7/twi_neo/twi_neo_pattern2_v1.7_10yrs.db
#
# 0.984 fbs_1.7/twi_neo/twi_neo_pattern3_v1.7_10yrs.db
#
# 0.987 fbs_1.7/twi_neo/twi_neo_pattern4_v1.7_10yrs.db
#
# 0.974 fbs_1.7/twi_neo/twi_neo_pattern5_v1.7_10yrs.db
#
# 0.976 fbs_1.7/twi_neo/twi_neo_pattern6_v1.7_10yrs.db
#
# 0.981 fbs_1.7/twi_neo/twi_neo_pattern7_v1.7_10yrs.db
#
# 0.993 fbs_1.7/u_long/u_long_ms_30_v1.7_10yrs.db
#
# 0.991 fbs_1.7/u_long/u_long_ms_40_v1.7_10yrs.db
#
# 0.983 fbs_1.7/u_long/u_long_ms_50_v1.7_10yrs.db
#
# 0.978 fbs_1.7/u_long/u_long_ms_60_v1.7_10yrs.db
#
# 1.007 fbs_1.7/wfd_cadence_drive/cadence_drive_gl100_gcbv1.7_10yrs.db
#
# 1.007 fbs_1.7/wfd_cadence_drive/cadence_drive_gl100v1.7_10yrs.db
#
# 0.996 fbs_1.7/wfd_cadence_drive/cadence_drive_gl200_gcbv1.7_10yrs.db
#
# 0.991 fbs_1.7/wfd_cadence_drive/cadence_drive_gl200v1.7_10yrs.db
#
# 1.011 fbs_1.7/wfd_cadence_drive/cadence_drive_gl30_gcbv1.7_10yrs.db
#
# 1.011 fbs_1.7/wfd_cadence_drive/cadence_drive_gl30v1.7_10yrs.db
#
# 1.010 fbs_1.7.1/new_rolling/baseline_nexp2_v1.7.1_10yrs.db
#
# 1.009 fbs_1.7.1/new_rolling/bulge_roll_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 1.002 fbs_1.7.1/new_rolling/bulge_roll_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 1.024 fbs_1.7.1/new_rolling/footprint_6_v1.7.1_10yrs.db
#
# 1.026 fbs_1.7.1/new_rolling/full_disk_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 1.020 fbs_1.7.1/new_rolling/full_disk_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 1.040 fbs_1.7.1/new_rolling/full_disk_v1.7_10yrs.db
#
# 0.983 fbs_1.7.1/new_rolling/rolling_nm_scale0.90_nslice2_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 0.975 fbs_1.7.1/new_rolling/rolling_nm_scale0.90_nslice3_fpw0.9_nrw1.0v1.7_10yrs.db
#
# 0.999 fbs_1.7.1/new_rolling/six_stripe_scale0.90_nslice6_fpw0.9_nrw0.0v1.7_10yrs.db

# %%
fileL4_17 = open('explore_footprints_L7_better.txt', 'r')
print("better astrometry")
Lines = fileL4_17.readlines()
for line in Lines:
    cutline=re.sub(".*:"," ",line)
    keep=cutline[0:12]
    grabname=re.sub("{'VolumeSum'.*","",line)
    volume=float(keep)
    fL4 = volume/baseline_L4_17
    print("{0:.3f}".format(fL4),grabname[10:])
# Out:
# better astrometry
# 1.107 fbs_1.7/baseline/baseline_nexp1_v1.7_10yrs.db
#
# 1.069 fbs_1.7/baseline/baseline_nexp2_v1.7_10yrs.db

# %%
baseline_L7_15_n1 = 225779.2804859185
baseline_L7_16_n1 = 222163.27262236737
baseline_L7_17_n2 = 212840.27030771854
baseline_L7_20_n2 = 204797.0416578286
baseline_L7_15_n2 = 217922.3901590727
baseline_L7_16_n2 = 214047.49963740897
baseline_L7_17_n1 = 221280.607090192
print("{0:.2f}".format(baseline_L7_15_n2/1e5))
print("{0:.2f}".format(baseline_L7_15_n1/1e5))
print("{0:.2f}".format(baseline_L7_16_n2/1e5))
print("{0:.2f}".format(baseline_L7_16_n1/1e5))
print("{0:.2f}".format(baseline_L7_17_n2/1e5))
print("{0:.2f}".format(baseline_L7_17_n1/1e5))
print("{0:.2f}".format(baseline_L7_20_n2/1e5))
# Out:
# 2.18
# 2.26
# 2.14
# 2.22
# 2.13
# 2.21
# 2.05

# %%
2.21/2.13
# Out:
# 1.0375586854460095
